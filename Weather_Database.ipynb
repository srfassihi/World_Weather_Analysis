# %%
# Import the dependencies
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | salym
# Processing Record 2 of Set 1 | kahama
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | talnakh
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | mutata
# Processing Record 9 of Set 1 | vestmannaeyjar
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | bathsheba
# Processing Record 12 of Set 1 | bandundu
# Processing Record 13 of Set 1 | zaysan
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | hornepayne
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | zhicheng
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | san felipe
# Processing Record 24 of Set 1 | kandrian
# Processing Record 25 of Set 1 | gladstone
# Processing Record 26 of Set 1 | catuday
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | yulara
# Processing Record 29 of Set 1 | burica
# City not found. Skipping...
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | muros
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | ostrovnoy
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | sao lourenco do sul
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | samana
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | flinders
# Processing Record 41 of Set 1 | khorramshahr
# Processing Record 42 of Set 1 | asau
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | haines junction
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | quito
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | cidreira
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | marystown
# Processing Record 4 of Set 2 | waddan
# Processing Record 5 of Set 2 | altagracia de orituco
# Processing Record 6 of Set 2 | saldanha
# Processing Record 7 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 2 | tigil
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | eresos
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | zvishavane
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | merritt island
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | cabo san lucas
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | palmer
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | tursunzoda
# Processing Record 23 of Set 2 | nikolskoye
# Processing Record 24 of Set 2 | manta
# Processing Record 25 of Set 2 | shingu
# Processing Record 26 of Set 2 | zaraza
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | aklavik
# Processing Record 29 of Set 2 | sawtell
# Processing Record 30 of Set 2 | novyy urengoy
# Processing Record 31 of Set 2 | soyo
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | corn island
# Processing Record 34 of Set 2 | mecca
# Processing Record 35 of Set 2 | lerwick
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | fuengirola
# Processing Record 41 of Set 2 | bantogon
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | denpasar
# Processing Record 45 of Set 2 | pinheiro machado
# Processing Record 46 of Set 2 | guerrero negro
# Processing Record 47 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | labuhan
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | komsomolskiy
# Processing Record 4 of Set 3 | aswan
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | alofi
# Processing Record 8 of Set 3 | mizdah
# Processing Record 9 of Set 3 | owatonna
# Processing Record 10 of Set 3 | santa maria
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | konstantinovka
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | kavaratti
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | sumenep
# Processing Record 19 of Set 3 | bulgan
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | wakkanai
# Processing Record 22 of Set 3 | angoche
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | sao joao da barra
# Processing Record 26 of Set 3 | bintulu
# Processing Record 27 of Set 3 | belmonte
# Processing Record 28 of Set 3 | brokopondo
# Processing Record 29 of Set 3 | tyukhtet
# Processing Record 30 of Set 3 | cape coast
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | kouango
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | escanaba
# Processing Record 38 of Set 3 | neosho
# Processing Record 39 of Set 3 | vila
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | carballo
# Processing Record 42 of Set 3 | binga
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | atar
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | martin
# Processing Record 47 of Set 3 | te anau
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | oussouye
# Processing Record 50 of Set 3 | kousseri
# Processing Record 1 of Set 4 | atuona
# Processing Record 2 of Set 4 | camiri
# Processing Record 3 of Set 4 | alta floresta
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | huarmey
# Processing Record 6 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 4 | kosh-agach
# Processing Record 8 of Set 4 | port alfred
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | saskylakh
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | lorengau
# Processing Record 14 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 4 | rabak
# Processing Record 16 of Set 4 | paranaiba
# Processing Record 17 of Set 4 | waiouru
# Processing Record 18 of Set 4 | rumphi
# Processing Record 19 of Set 4 | sorong
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | joao pinheiro
# Processing Record 23 of Set 4 | srednekolymsk
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | tineo
# Processing Record 28 of Set 4 | sakakah
# Processing Record 29 of Set 4 | norman wells
# Processing Record 30 of Set 4 | cotonou
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | puerto escondido
# Processing Record 33 of Set 4 | bubaque
# Processing Record 34 of Set 4 | honningsvag
# Processing Record 35 of Set 4 | faanui
# Processing Record 36 of Set 4 | raga
# Processing Record 37 of Set 4 | mirnyy
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | sualkuchi
# Processing Record 40 of Set 4 | gornyy
# Processing Record 41 of Set 4 | altay
# Processing Record 42 of Set 4 | butaritari
# Processing Record 43 of Set 4 | surgut
# Processing Record 44 of Set 4 | kahului
# Processing Record 45 of Set 4 | ilulissat
# Processing Record 46 of Set 4 | lokosovo
# Processing Record 47 of Set 4 | riachao das neves
# Processing Record 48 of Set 4 | caravelas
# Processing Record 49 of Set 4 | ahmadpur
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 5 | bonthe
# Processing Record 3 of Set 5 | halifax
# Processing Record 4 of Set 5 | tuktoyaktuk
# Processing Record 5 of Set 5 | hovd
# Processing Record 6 of Set 5 | okhotsk
# Processing Record 7 of Set 5 | afgoye
# City not found. Skipping...
# Processing Record 8 of Set 5 | ghanzi
# Processing Record 9 of Set 5 | chissamba
# Processing Record 10 of Set 5 | tabou
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | khandbari
# Processing Record 13 of Set 5 | nantucket
# Processing Record 14 of Set 5 | kabare
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 5 | sabha
# Processing Record 18 of Set 5 | maumere
# Processing Record 19 of Set 5 | camacha
# Processing Record 20 of Set 5 | vanimo
# Processing Record 21 of Set 5 | fomboni
# Processing Record 22 of Set 5 | soke
# Processing Record 23 of Set 5 | ust-maya
# Processing Record 24 of Set 5 | nautla
# Processing Record 25 of Set 5 | portland
# Processing Record 26 of Set 5 | pandan
# Processing Record 27 of Set 5 | iskele
# Processing Record 28 of Set 5 | bengkulu
# Processing Record 29 of Set 5 | kieta
# Processing Record 30 of Set 5 | bilibino
# Processing Record 31 of Set 5 | vardo
# Processing Record 32 of Set 5 | matay
# Processing Record 33 of Set 5 | vuktyl
# Processing Record 34 of Set 5 | lakatoro
# Processing Record 35 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 5 | macau
# Processing Record 37 of Set 5 | manggar
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | baghdad
# Processing Record 40 of Set 5 | kapoeta
# Processing Record 41 of Set 5 | sorland
# Processing Record 42 of Set 5 | yar-sale
# Processing Record 43 of Set 5 | pauini
# Processing Record 44 of Set 5 | kenai
# Processing Record 45 of Set 5 | pingliang
# Processing Record 46 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | conceicao da barra
# Processing Record 48 of Set 5 | banda aceh
# Processing Record 49 of Set 5 | batesville
# Processing Record 50 of Set 5 | seymchan
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | khandyga
# Processing Record 3 of Set 6 | ikom
# Processing Record 4 of Set 6 | merauke
# Processing Record 5 of Set 6 | lompoc
# Processing Record 6 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 6 | nisia floresta
# Processing Record 8 of Set 6 | patabog
# Processing Record 9 of Set 6 | imbituba
# Processing Record 10 of Set 6 | juneau
# Processing Record 11 of Set 6 | ixtapa
# Processing Record 12 of Set 6 | bang saphan
# Processing Record 13 of Set 6 | igarka
# Processing Record 14 of Set 6 | kimparana
# Processing Record 15 of Set 6 | georgiyevskoye
# Processing Record 16 of Set 6 | pangnirtung
# Processing Record 17 of Set 6 | venezuela
# Processing Record 18 of Set 6 | grindavik
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | atambua
# Processing Record 21 of Set 6 | tecoanapa
# Processing Record 22 of Set 6 | manzhouli
# Processing Record 23 of Set 6 | hithadhoo
# Processing Record 24 of Set 6 | victor harbor
# Processing Record 25 of Set 6 | seydi
# Processing Record 26 of Set 6 | shiogama
# Processing Record 27 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 6 | taltal
# Processing Record 29 of Set 6 | aksarka
# Processing Record 30 of Set 6 | pa sang
# Processing Record 31 of Set 6 | sterling
# Processing Record 32 of Set 6 | astana
# Processing Record 33 of Set 6 | dergachi
# Processing Record 34 of Set 6 | kavieng
# Processing Record 35 of Set 6 | saint george
# Processing Record 36 of Set 6 | zhigansk
# Processing Record 37 of Set 6 | kyzyl-suu
# Processing Record 38 of Set 6 | kuala terengganu
# Processing Record 39 of Set 6 | monte plata
# Processing Record 40 of Set 6 | biak
# Processing Record 41 of Set 6 | tomohon
# Processing Record 42 of Set 6 | mareeba
# Processing Record 43 of Set 6 | jinchang
# Processing Record 44 of Set 6 | dickinson
# Processing Record 45 of Set 6 | kuzino
# Processing Record 46 of Set 6 | clyde river
# Processing Record 47 of Set 6 | dzhebariki-khaya
# Processing Record 48 of Set 6 | salinopolis
# Processing Record 49 of Set 6 | marzuq
# Processing Record 50 of Set 6 | vaitape
# Processing Record 1 of Set 7 | constitucion
# Processing Record 2 of Set 7 | naze
# Processing Record 3 of Set 7 | san andres
# Processing Record 4 of Set 7 | hofn
# Processing Record 5 of Set 7 | port-gentil
# Processing Record 6 of Set 7 | katangli
# Processing Record 7 of Set 7 | barra patuca
# Processing Record 8 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 7 | seoul
# Processing Record 10 of Set 7 | mao
# Processing Record 11 of Set 7 | aguimes
# Processing Record 12 of Set 7 | kinablangan
# Processing Record 13 of Set 7 | mongagua
# Processing Record 14 of Set 7 | castelo do piaui
# Processing Record 15 of Set 7 | nizwa
# Processing Record 16 of Set 7 | rosita
# Processing Record 17 of Set 7 | vostok
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | yuksekova
# Processing Record 20 of Set 7 | dingle
# Processing Record 21 of Set 7 | general roca
# Processing Record 22 of Set 7 | rudbar
# Processing Record 23 of Set 7 | thinadhoo
# Processing Record 24 of Set 7 | namwala
# Processing Record 25 of Set 7 | fukue
# Processing Record 26 of Set 7 | lesogorsk
# Processing Record 27 of Set 7 | kalemie
# Processing Record 28 of Set 7 | oyem
# Processing Record 29 of Set 7 | stonewall
# Processing Record 30 of Set 7 | arlit
# Processing Record 31 of Set 7 | chikoy
# City not found. Skipping...
# Processing Record 32 of Set 7 | puerto leguizamo
# Processing Record 33 of Set 7 | sitka
# Processing Record 34 of Set 7 | grand gaube
# Processing Record 35 of Set 7 | hualmay
# Processing Record 36 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 7 | batagay-alyta
# Processing Record 38 of Set 7 | kristinehamn
# Processing Record 39 of Set 7 | pleshanovo
# Processing Record 40 of Set 7 | multan
# Processing Record 41 of Set 7 | luganville
# Processing Record 42 of Set 7 | dubbo
# Processing Record 43 of Set 7 | fenelon falls
# Processing Record 44 of Set 7 | hailey
# Processing Record 45 of Set 7 | albanel
# Processing Record 46 of Set 7 | hay river
# Processing Record 47 of Set 7 | belaya gora
# Processing Record 48 of Set 7 | iguape
# Processing Record 49 of Set 7 | kushima
# Processing Record 50 of Set 7 | morti
# City not found. Skipping...
# Processing Record 1 of Set 8 | santa vitoria do palmar
# Processing Record 2 of Set 8 | dicabisagan
# Processing Record 3 of Set 8 | christiana
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 7 of Set 8 | magole
# Processing Record 8 of Set 8 | souillac
# Processing Record 9 of Set 8 | mitu
# Processing Record 10 of Set 8 | arman
# Processing Record 11 of Set 8 | zhuhai
# Processing Record 12 of Set 8 | lakes entrance
# Processing Record 13 of Set 8 | thabazimbi
# Processing Record 14 of Set 8 | turukhansk
# Processing Record 15 of Set 8 | maldonado
# Processing Record 16 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 8 | sebeta
# Processing Record 18 of Set 8 | chardara
# Processing Record 19 of Set 8 | gigmoto
# Processing Record 20 of Set 8 | chuy
# Processing Record 21 of Set 8 | am timan
# Processing Record 22 of Set 8 | genova
# Processing Record 23 of Set 8 | calabozo
# Processing Record 24 of Set 8 | oranjemund
# Processing Record 25 of Set 8 | nipawin
# Processing Record 26 of Set 8 | limon
# Processing Record 27 of Set 8 | pedasi
# Processing Record 28 of Set 8 | bandarbeyla
# Processing Record 29 of Set 8 | abalak
# Processing Record 30 of Set 8 | nuuk
# Processing Record 31 of Set 8 | maceio
# Processing Record 32 of Set 8 | vilaka
# Processing Record 33 of Set 8 | zhezkazgan
# Processing Record 34 of Set 8 | arroyo
# Processing Record 35 of Set 8 | adrar
# Processing Record 36 of Set 8 | plettenberg bay
# Processing Record 37 of Set 8 | kushmurun
# Processing Record 38 of Set 8 | bhag
# Processing Record 39 of Set 8 | unity
# Processing Record 40 of Set 8 | varhaug
# Processing Record 41 of Set 8 | half moon bay
# Processing Record 42 of Set 8 | dong hoi
# Processing Record 43 of Set 8 | trinidad
# Processing Record 44 of Set 8 | port hedland
# Processing Record 45 of Set 8 | hambantota
# Processing Record 46 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 8 | calatayud
# Processing Record 48 of Set 8 | huntington
# Processing Record 49 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 8 | luderitz
# Processing Record 1 of Set 9 | lagoa
# Processing Record 2 of Set 9 | chumikan
# Processing Record 3 of Set 9 | bafq
# Processing Record 4 of Set 9 | port macquarie
# Processing Record 5 of Set 9 | jalu
# Processing Record 6 of Set 9 | sept-iles
# Processing Record 7 of Set 9 | acapulco
# Processing Record 8 of Set 9 | mogadishu
# Processing Record 9 of Set 9 | srandakan
# Processing Record 10 of Set 9 | katsuura
# Processing Record 11 of Set 9 | laguna
# Processing Record 12 of Set 9 | kondoa
# Processing Record 13 of Set 9 | grand-santi
# Processing Record 14 of Set 9 | havre-saint-pierre
# Processing Record 15 of Set 9 | tilichiki
# Processing Record 16 of Set 9 | nishihara
# Processing Record 17 of Set 9 | avera
# Processing Record 18 of Set 9 | verkhnyaya sinyachikha
# Processing Record 19 of Set 9 | great falls
# Processing Record 20 of Set 9 | bonavista
# Processing Record 21 of Set 9 | puerto penasco
# Processing Record 22 of Set 9 | agua dulce
# Processing Record 23 of Set 9 | camopi
# Processing Record 24 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 9 | vila velha
# Processing Record 26 of Set 9 | ahipara
# Processing Record 27 of Set 9 | karacakoy
# Processing Record 28 of Set 9 | hvolsvollur
# Processing Record 29 of Set 9 | makakilo city
# Processing Record 30 of Set 9 | talas
# Processing Record 31 of Set 9 | eureka
# Processing Record 32 of Set 9 | lujan
# Processing Record 33 of Set 9 | vao
# Processing Record 34 of Set 9 | tautira
# Processing Record 35 of Set 9 | paamiut
# Processing Record 36 of Set 9 | sangar
# Processing Record 37 of Set 9 | mehriz
# Processing Record 38 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 9 | huanren
# Processing Record 40 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 9 | la palma
# Processing Record 42 of Set 9 | miri
# Processing Record 43 of Set 9 | santiago del estero
# Processing Record 44 of Set 9 | oktyabrskoye
# Processing Record 45 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 9 | fare
# Processing Record 47 of Set 9 | wajima
# Processing Record 48 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 49 of Set 9 | bedesa
# Processing Record 50 of Set 9 | saint-georges
# Processing Record 1 of Set 10 | baruun-urt
# Processing Record 2 of Set 10 | kytmanovo
# Processing Record 3 of Set 10 | leh
# Processing Record 4 of Set 10 | ginda
# Processing Record 5 of Set 10 | sioux lookout
# Processing Record 6 of Set 10 | mangla
# Processing Record 7 of Set 10 | bereda
# Processing Record 8 of Set 10 | mezohegyes
# Processing Record 9 of Set 10 | boa vista
# Processing Record 10 of Set 10 | husavik
# Processing Record 11 of Set 10 | roald
# Processing Record 12 of Set 10 | saint-jean-de-maurienne
# Processing Record 13 of Set 10 | quimper
# Processing Record 14 of Set 10 | semikarakorsk
# Processing Record 15 of Set 10 | olafsvik
# Processing Record 16 of Set 10 | kibaya
# Processing Record 17 of Set 10 | beloha
# Processing Record 18 of Set 10 | betafo
# Processing Record 19 of Set 10 | sobolevo
# Processing Record 20 of Set 10 | tres arroyos
# Processing Record 21 of Set 10 | faya
# Processing Record 22 of Set 10 | abu kamal
# Processing Record 23 of Set 10 | andros town
# Processing Record 24 of Set 10 | tezu
# Processing Record 25 of Set 10 | fairbanks
# Processing Record 26 of Set 10 | flin flon
# Processing Record 27 of Set 10 | itarema
# Processing Record 28 of Set 10 | kundiawa
# Processing Record 29 of Set 10 | ugoofaaru
# Processing Record 30 of Set 10 | kondinskoye
# Processing Record 31 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 10 | dunedin
# Processing Record 33 of Set 10 | klyuchi
# Processing Record 34 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 10 | comodoro rivadavia
# Processing Record 36 of Set 10 | tabuleiro do norte
# Processing Record 37 of Set 10 | sao felix do xingu
# Processing Record 38 of Set 10 | ambulu
# Processing Record 39 of Set 10 | broken hill
# Processing Record 40 of Set 10 | la primavera
# Processing Record 41 of Set 10 | roura
# Processing Record 42 of Set 10 | beringovskiy
# Processing Record 43 of Set 10 | nyurba
# Processing Record 44 of Set 10 | yumen
# Processing Record 45 of Set 10 | madang
# Processing Record 46 of Set 10 | tawau
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 10 | tolaga bay
# Processing Record 50 of Set 10 | ganzhou
# Processing Record 1 of Set 11 | northam
# Processing Record 2 of Set 11 | porto novo
# Processing Record 3 of Set 11 | ilhabela
# Processing Record 4 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 11 | udachnyy
# Processing Record 6 of Set 11 | carutapera
# Processing Record 7 of Set 11 | severnyy
# Processing Record 8 of Set 11 | pokrovka
# Processing Record 9 of Set 11 | anuchino
# Processing Record 10 of Set 11 | zhanaozen
# Processing Record 11 of Set 11 | guarda
# Processing Record 12 of Set 11 | kurilsk
# Processing Record 13 of Set 11 | maneromango
# Processing Record 14 of Set 11 | gat
# Processing Record 15 of Set 11 | cortez
# Processing Record 16 of Set 11 | kachug
# Processing Record 17 of Set 11 | taitung
# Processing Record 18 of Set 11 | port hardy
# Processing Record 19 of Set 11 | ipojuca
# Processing Record 20 of Set 11 | finnsnes
# Processing Record 21 of Set 11 | luorong
# Processing Record 22 of Set 11 | minas
# Processing Record 23 of Set 11 | lata
# Processing Record 24 of Set 11 | ca mau
# Processing Record 25 of Set 11 | ulladulla
# Processing Record 26 of Set 11 | pacific grove
# Processing Record 27 of Set 11 | nome
# Processing Record 28 of Set 11 | korla
# Processing Record 29 of Set 11 | saint-leu
# Processing Record 30 of Set 11 | port blair
# Processing Record 31 of Set 11 | lazaro cardenas
# Processing Record 32 of Set 11 | karasburg
# Processing Record 33 of Set 11 | eenhana
# Processing Record 34 of Set 11 | huaiyin
# Processing Record 35 of Set 11 | gamba
# Processing Record 36 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 11 | derzhavinsk
# Processing Record 38 of Set 11 | verkhoyansk
# Processing Record 39 of Set 11 | maryville
# Processing Record 40 of Set 11 | hengshui
# Processing Record 41 of Set 11 | padang
# Processing Record 42 of Set 11 | umm kaddadah
# Processing Record 43 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 11 | hami
# Processing Record 45 of Set 11 | vila franca do campo
# Processing Record 46 of Set 11 | christchurch
# Processing Record 47 of Set 11 | pregradnoye
# Processing Record 48 of Set 11 | otta
# Processing Record 49 of Set 11 | chara
# Processing Record 50 of Set 11 | chekmagush
# Processing Record 1 of Set 12 | eskil
# Processing Record 2 of Set 12 | inhambane
# Processing Record 3 of Set 12 | praia da vitoria
# Processing Record 4 of Set 12 | mikhaylovka
# Processing Record 5 of Set 12 | kavali
# Processing Record 6 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 7 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 8 of Set 12 | prince rupert
# Processing Record 9 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 12 | miguelopolis
# Processing Record 11 of Set 12 | road town
# Processing Record 12 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 13 of Set 12 | bira
# Processing Record 14 of Set 12 | urumqi
# Processing Record 15 of Set 12 | solwezi
# Processing Record 16 of Set 12 | newport
# Processing Record 17 of Set 12 | sabang
# Processing Record 18 of Set 12 | the valley
# Processing Record 19 of Set 12 | mayo
# Processing Record 20 of Set 12 | quthing
# Processing Record 21 of Set 12 | ola
# Processing Record 22 of Set 12 | omsukchan
# Processing Record 23 of Set 12 | angoram
# Processing Record 24 of Set 12 | hauterive
# Processing Record 25 of Set 12 | kudahuvadhoo
# Processing Record 26 of Set 12 | price
# Processing Record 27 of Set 12 | biskamzha
# Processing Record 28 of Set 12 | kismayo
# Processing Record 29 of Set 12 | mildura
# Processing Record 30 of Set 12 | necochea
# Processing Record 31 of Set 12 | oparino
# Processing Record 32 of Set 12 | charters towers
# Processing Record 33 of Set 12 | villafranca de los barros
# Processing Record 34 of Set 12 | ye
# City not found. Skipping...
# Processing Record 35 of Set 12 | chapais
# Processing Record 36 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 12 | naruto
# Processing Record 38 of Set 12 | ciudad bolivar
# Processing Record 39 of Set 12 | sechura
# Processing Record 40 of Set 12 | lingyuan
# Processing Record 41 of Set 12 | tanete
# Processing Record 42 of Set 12 | kedrovyy
# Processing Record 43 of Set 12 | okha
# Processing Record 44 of Set 12 | salta
# Processing Record 45 of Set 12 | atherton
# Processing Record 46 of Set 12 | atraulia
# Processing Record 47 of Set 12 | ares
# Processing Record 48 of Set 12 | lamu
# Processing Record 49 of Set 12 | vysokogornyy
# Processing Record 50 of Set 12 | callaway
# Processing Record 1 of Set 13 | taoudenni
# Processing Record 2 of Set 13 | tauranga
# Processing Record 3 of Set 13 | sibolga
# Processing Record 4 of Set 13 | cervo
# Processing Record 5 of Set 13 | bridgetown
# Processing Record 6 of Set 13 | sembabule
# Processing Record 7 of Set 13 | baoying
# Processing Record 8 of Set 13 | hamilton
# Processing Record 9 of Set 13 | zhanakorgan
# Processing Record 10 of Set 13 | inta
# Processing Record 11 of Set 13 | homer
# Processing Record 12 of Set 13 | sovetskaya gavan
# Processing Record 13 of Set 13 | santa ana
# Processing Record 14 of Set 13 | cockburn town
# Processing Record 15 of Set 13 | mount gambier
# Processing Record 16 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 17 of Set 13 | legnago
# Processing Record 18 of Set 13 | divnogorsk
# Processing Record 19 of Set 13 | aldine
# Processing Record 20 of Set 13 | motril
# Processing Record 21 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 13 | calabar
# Processing Record 23 of Set 13 | rawson
# Processing Record 24 of Set 13 | champerico
# Processing Record 25 of Set 13 | atasu
# Processing Record 26 of Set 13 | kharan
# Processing Record 27 of Set 13 | palasa
# Processing Record 28 of Set 13 | provideniya
# Processing Record 29 of Set 13 | ljungby
# Processing Record 30 of Set 13 | saiha
# Processing Record 31 of Set 13 | skibbereen
# Processing Record 32 of Set 13 | tubuala
# Processing Record 33 of Set 13 | tulun
# Processing Record 34 of Set 13 | keti bandar
# Processing Record 35 of Set 13 | gisborne
# Processing Record 36 of Set 13 | wanning
# Processing Record 37 of Set 13 | kiunga
# Processing Record 38 of Set 13 | tessalit
# Processing Record 39 of Set 13 | narrabri
# Processing Record 40 of Set 13 | surt
# Processing Record 41 of Set 13 | tumut
# Processing Record 42 of Set 13 | mukhen
# Processing Record 43 of Set 13 | nhulunbuy
# Processing Record 44 of Set 13 | semirom
# Processing Record 45 of Set 13 | beaverlodge
# Processing Record 46 of Set 13 | kaniama
# Processing Record 47 of Set 13 | jos
# Processing Record 48 of Set 13 | yala
# Processing Record 49 of Set 13 | nabire
# Processing Record 50 of Set 13 | arica
# Processing Record 1 of Set 14 | harper
# Processing Record 2 of Set 14 | la orilla
# Processing Record 3 of Set 14 | felanitx
# Processing Record 4 of Set 14 | yeysk
# Processing Record 5 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 14 | kosum phisai
# Processing Record 7 of Set 14 | pucara
# Processing Record 8 of Set 14 | saint anthony
# Processing Record 9 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 14 | teseney
# Processing Record 11 of Set 14 | kungurtug
# Processing Record 12 of Set 14 | martil
# Processing Record 13 of Set 14 | little chute
# Processing Record 14 of Set 14 | imeni poliny osipenko
# Processing Record 15 of Set 14 | papayal
# Processing Record 16 of Set 14 | greenville
# Processing Record 17 of Set 14 | zlobin
# Processing Record 18 of Set 14 | mongo
# Processing Record 19 of Set 14 | basoko
# Processing Record 20 of Set 14 | geraldton
# Processing Record 21 of Set 14 | joshimath
# Processing Record 22 of Set 14 | solnechnyy
# Processing Record 23 of Set 14 | moree
# Processing Record 24 of Set 14 | walvis bay
# Processing Record 25 of Set 14 | at-bashi
# Processing Record 26 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 14 | tehachapi
# Processing Record 28 of Set 14 | gamboma
# Processing Record 29 of Set 14 | nombre de dios
# Processing Record 30 of Set 14 | ucluelet
# Processing Record 31 of Set 14 | bambanglipuro
# Processing Record 32 of Set 14 | omboue
# Processing Record 33 of Set 14 | pemba
# Processing Record 34 of Set 14 | olinda
# Processing Record 35 of Set 14 | altayskoye
# Processing Record 36 of Set 14 | sembe
# Processing Record 37 of Set 14 | norden
# Processing Record 38 of Set 14 | valer
# Processing Record 39 of Set 14 | westport
# Processing Record 40 of Set 14 | pastos bons
# Processing Record 41 of Set 14 | sjovegan
# Processing Record 42 of Set 14 | kaz
# Processing Record 43 of Set 14 | the pas
# Processing Record 44 of Set 14 | tevaitoa
# Processing Record 45 of Set 14 | baykit
# Processing Record 46 of Set 14 | ponta delgada
# Processing Record 47 of Set 14 | yerkoy
# Processing Record 48 of Set 14 | batemans bay
# Processing Record 49 of Set 14 | ayorou
# Processing Record 50 of Set 14 | akyab
# Processing Record 1 of Set 15 | deep river
# Processing Record 2 of Set 15 | peniche
# Processing Record 3 of Set 15 | grenfell
# Processing Record 4 of Set 15 | byron bay
# Processing Record 5 of Set 15 | tucuman
# Processing Record 6 of Set 15 | chenghai
# Processing Record 7 of Set 15 | koraput
# Processing Record 8 of Set 15 | przhevalskoye
# Processing Record 9 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 10 of Set 15 | beian
# Processing Record 11 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 15 | hwange
# Processing Record 13 of Set 15 | aleppo
# Processing Record 14 of Set 15 | london
# Processing Record 15 of Set 15 | ivankiv
# Processing Record 16 of Set 15 | slavuta
# Processing Record 17 of Set 15 | borba
# Processing Record 18 of Set 15 | snezhnogorsk
# Processing Record 19 of Set 15 | papara
# Processing Record 20 of Set 15 | lasa
# Processing Record 21 of Set 15 | juba
# Processing Record 22 of Set 15 | port augusta
# Processing Record 23 of Set 15 | odweyne
# Processing Record 24 of Set 15 | mount isa
# Processing Record 25 of Set 15 | goderich
# Processing Record 26 of Set 15 | tomatlan
# Processing Record 27 of Set 15 | porto nacional
# Processing Record 28 of Set 15 | oranjestad
# Processing Record 29 of Set 15 | trairi
# Processing Record 30 of Set 15 | whitianga
# Processing Record 31 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 15 | kupang
# Processing Record 33 of Set 15 | luanda
# Processing Record 34 of Set 15 | salalah
# Processing Record 35 of Set 15 | qaqortoq
# Processing Record 36 of Set 15 | kirovskiy
# Processing Record 37 of Set 15 | ushtobe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Salym      RU  60.0625   71.4789      4.35        96          76
# 1          Kahama      TZ  -3.8333   32.6000     71.38        63          41
# 2         Rikitea      PF -23.1203 -134.9692     76.60        77          18
# 3         Talnakh      RU  69.4865   88.3972     11.43        95         100
# 4          Kodiak      US  57.7900 -152.4072     20.71        63          90
# 5     New Norfolk      AU -42.7826  147.0587     56.66        63          10
# 6         Ushuaia      AR -54.8000  -68.3000     49.66        57          40
# 7          Mutata      CO   7.2441  -76.4356     78.60        90         100
# 8  Vestmannaeyjar      IS  63.4427  -20.2734     33.57        63         100
# 9         Mataura      NZ -46.1927  168.8643     55.99        61         100
#
#    Wind Speed Current Description
# 0        6.98       broken clouds
# 1        4.47    scattered clouds
# 2       14.92          few clouds
# 3        7.83     overcast clouds
# 4       12.66     overcast clouds
# 5        1.99           clear sky
# 6       26.46    scattered clouds
# 7        0.43     overcast clouds
# 8       11.39     overcast clouds
# 9        2.57     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
